# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd 'drive/MyDrive/Fishchecker Colab'
# Out:
# /content/drive/MyDrive/Fishchecker Colab

# %%
from python.util.video2img import video2img
from python.util.rotationimg import *
from python.util.cal import *
from google.colab.patches import cv2_imshow

from PIL import Image
import pandas as pd
import numpy as np
import cv2
import re
import time

# %%
st = time.time()
filename = 'test'
video2img(file=filename)
# %cd ./python/classifiers/yolov7
# !python detect.py --weights v14_best.pt --img 640 --source 'testdata/images/test'

# Frame choice(가장 넓은 면적)
f = open('xyxy.txt')
lines = f.readlines()
_lines = []
for l in lines[::-1]:
  #print(l.split('/'))
  if re.match('frame', l.split('/')[0]):
    _lines.append(l.split('/'))
f.close()
_lines.sort(key=lambda x:int(x[2]), reverse=True)
bestframe = _lines[0][0]
bestframepath = 'testdata/images/'+filename+'/%s'%bestframe

species = list(np.array(_lines).T[1])
species = max(species, key=species.count)


# Choice한 frame rotation
best_img = Image.open(bestframepath)
[best_img.rotate(i).save('./rotatedimg/rotate'+str(i)+'.jpg') for i in range(0,91,5)]
[best_img.rotate(i).save('./rotatedimg/rotate'+str(i)+'.jpg') for i in range(-1,-91,-5)]

# !python detect.py --weights v14_best.pt --img 640 --source './rotatedimg/'

f = open('xyxy.txt')
lines = f.readlines()
_lines = []
for l in lines[::-1]:
  #print(l.split('/'))
  if re.match('rotate', l.split('/')[0]):
    _lines.append(l.split('/'))
f.close()
_lines.sort(key=lambda x:int(x[4]), reverse = False)
rotatedbestframe = _lines[0]
rotatedbestframepath = 'rotatedimg/%s'%rotatedbestframe[0]
fishIL = int(rotatedbestframe[3])

bgrLower = np.array([10, 0, 10])    # 추출할 색의 하한(BGR)
bgrUpper = np.array([255, 136, 100])    # 추출할 색의 상한(BGR)
for _ in _lines:
  _img = cv2.imread('./rotatedimg/'+_[0], cv2.IMREAD_UNCHANGED)
  #cv2_imshow(_img)
  img_mask = cv2.inRange(_img, bgrLower, bgrUpper) # BGR로 부터 마스크를 작성
  result = cv2.bitwise_and(_img, _img, mask=img_mask) # 원본 이미지와 마스크를 합성
  #_img.save('/bongimg/bongimg_'+_[0])
  cv2.imwrite('./bongimg/bongimg'+_[0], result)

# !python detect.py --weights bong_v5_best.pt --img 640 --source './bongimg/'

f = open('xyxy.txt')
lines = f.readlines()
_lines = []
for l in lines[::-1]:
  #print(l.split('/'))
  if re.match('bongimg', l.split('/')[0]):
    _lines.append(l.split('/'))
f.close()
f = open("xyxy.txt", 'w')
f.close()
_lines.sort(key=lambda x:int(x[4]), reverse = False)

bongIT = int(_lines[0][4])



fishTL = cal_fishTL(fishIL, bongIT)
weight = cal_weight(species, fishTL)

pd.set_option('display.max_colwidth', -1)
info = pd.DataFrame(speciesinfo[species]).T
info.columns = ["Species", "분포", "구별법", "추천음식"]
info.insert(1, "Length (TL)", [str(round(fishTL, 3)) + 'cm'])
info.insert(2, "Weight (WW)", [str(round(weight, 3)) + 'g'])
info = info.rename(index = {0:species})
print(time.time()-st,"s")
info
# Out:
# /content/drive/MyDrive/Fishchecker Colab/python/util /content/drive/MyDrive/Fishchecker Colab/python
# ./python/classifiers/yolov7/testdata/test.mp4
# Video2Img complete
# /content/drive/MyDrive/Fishchecker Colab/python/classifiers/yolov7
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='testdata/images/test', update=False, view_img=False, weights=['v14_best.pt'])
# YOLOR 🚀 2022-8-16 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# IAuxDetect.fuse
# Model Summary: 370 layers, 80978600 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1 G, Done. (23.4ms) Inference, (42.4ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame0.jpg
# 1 G, Done. (21.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame10.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame100.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame105.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame110.jpg
# 1 G, Done. (21.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame115.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame120.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame125.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame130.jpg
# 1 G, Done. (21.6ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame135.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame140.jpg
# 1 G, Done. (21.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame145.jpg
# 1 G, Done. (21.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame15.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame150.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame155.jpg
# 1 G, Done. (21.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame20.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame25.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame30.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame35.jpg
# 1 G, Done. (21.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame40.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame45.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame5.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame50.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame55.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame60.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame65.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame70.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame75.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame80.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame85.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame90.jpg
# 1 G, Done. (23.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp4/frame95.jpg
# Done. (2.963s)
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./rotatedimg/', update=False, view_img=False, weights=['v14_best.pt'])
# YOLOR 🚀 2022-8-16 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# IAuxDetect.fuse
# Model Summary: 370 layers, 80978600 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1 G, Done. (23.4ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-1.jpg
# 1 G, Done. (21.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-11.jpg
# 1 G, Done. (21.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-16.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-21.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-26.jpg
# 1 G, Done. (21.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-31.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-36.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-41.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-46.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-51.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-56.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-6.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-61.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-66.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-71.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-76.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-81.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate-86.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate0.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate10.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate15.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate20.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate25.jpg
# 1 G, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate30.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate35.jpg
# 1 G, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate40.jpg
# 1 G, Done. (21.5ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate45.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate5.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate50.jpg
# 1 G, Done. (21.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate55.jpg
# 1 G, Done. (21.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate60.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate65.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate70.jpg
# 1 G, Done. (21.5ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate75.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate80.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate85.jpg
# 1 G, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp5/rotate90.jpg
# Done. (3.041s)
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./bongimg/', update=False, view_img=False, weights=['bong_v5_best.pt'])
# YOLOR 🚀 2022-8-16 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# IAuxDetect.fuse
# Model Summary: 370 layers, 80909336 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1 B, Done. (23.3ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-1.jpg
# 1 B, Done. (21.8ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-11.jpg
# 1 B, Done. (21.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-16.jpg
# 1 B, Done. (21.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-21.jpg
# 2 Bs, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-26.jpg
# 2 Bs, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-31.jpg
# 1 B, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-36.jpg
# Done. (21.6ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-41.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-46.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-51.jpg
# Done. (21.5ms) Inference, (0.3ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-56.jpg
# 1 B, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-6.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-61.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-66.jpg
# Done. (21.6ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-71.jpg
# Done. (21.5ms) Inference, (0.3ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-76.jpg
# Done. (21.6ms) Inference, (0.3ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-81.jpg
# 1 B, Done. (21.6ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate-86.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate0.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate10.jpg
# 1 B, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate15.jpg
# 1 B, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate20.jpg
# 1 B, Done. (21.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate25.jpg
# 2 Bs, Done. (21.5ms) Inference, (0.8ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate30.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate35.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate40.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate45.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate5.jpg
# 1 B, Done. (21.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate50.jpg
# 1 B, Done. (21.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate55.jpg
# 2 Bs, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate60.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate65.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate70.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate75.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate80.jpg
# 1 B, Done. (21.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate85.jpg
# Done. (21.5ms) Inference, (0.2ms) NMS
#  The image with the result is saved in: runs/detect/exp6/bongimgrotate90.jpg
# Done. (3.515s)
# 105.01287198066711 s
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                    Species Length (TL) Weight (WW)  \
# G  고등어 : Scomber Japonicus  24.666cm    118.373g
#
#                                       분포  \
# G  태평양 (한국 남부, 일본에서 마이크로네시아, 호주 북부), 인도양
#
#                                                                                                        구별법  \
# G  몸 등쪽은 짙은 청색을 띠며 중앙에서부터 밝아져 배쪽은 은백색을 띤다.주새개골의 끝에는 검은색 얼룩 점이 있다. 모든 지느러미는 희거나 무색투명하며, 꼬리지느러미만 어두운 갈색을 띤다.
#
#                                                                           추천음식
# G  1. 고등어 조림 2. 고갈비 3. 고등어 강정 4. 고등어 샌드위치  5. 고등어 찌개  6. 깐풍 고등어 7. 고등어 된장구이 초밥
